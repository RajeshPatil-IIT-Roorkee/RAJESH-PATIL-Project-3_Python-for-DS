# %% [markdown]
# # <p style="text-align:center; color:blue;"> Machine Learning - Web Develpoment Using Flask : Graded Project 3</p>

# %% [markdown]
# ## Domain : <font color="#338CFF">Finance and Banking</font>

# %% [markdown]
# ### Context :

# %% [markdown]
# Dream Housing Finance company deals in all home loans. They have presence
# across all urban, semi urban and rural areas. Customers first apply for a home
# loan after that company manually validates the customer eligibility for loan.
# Company wants to automate the loan eligibility process based on customer
# detail provided while filling the details online.
# They need a web application where a user can access their website and
# register, login, and enter the required details such as Gender, Marital Status,
# Education, Number of Dependents, Income, Loan Amount, Credit History and
# others for checking the eligibility for the home loan.

# %% [markdown]
# ### Project Objective :

# %% [markdown]
# 1) This is a standard supervised classification task. A classification problem where we have to predict whether a customer is eligible for loan or not based on a given set of independent variable(s).
# 2) To build a Python Flask ML application where a user has to get registered by entering the username and password and login to the website and then enter their details to check whether they are eligible for loan or not.

# %% [markdown]
# ### Dataset Description :

# %% [markdown]
# Dataset can be found __[here](https://www.kaggle.com/datasets/ssiddharth408/loan-prediction-dataset)__.

# %% [markdown]
# 1. Loan ID Unique Loan ID
# 2. Gender Male or Female
# 3. Married Applicant married (Y/N)
# 4. Dependents Number of dependents
# 5. Self employed Self employed (Y/N)
# 6. Education Graduate/Undergraduate
# 7. Applicant Income Applicant income (in dollars)
# 8. Co Applicant Income Co Applicant Income (in dollars)
# 9. Loan Amount Loan amount in thousands (in dollars)
# 10. Loan Amount Term Term of loan in months
# 11. Credit History Credit history meets guidelines Yes/No(1/0)
# 12. Property area Urban/Semi Urban/Rural
# 13. Loan Status (Target) Loan Approved (Y/N)

# %% [markdown]
# # <font color=#338CFF>● Model Building and saving the model using Pickle</font>

# %% [markdown]
# ### 1. Import required libraries and read the dataset.

# %%
## Importing required libraries 

import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = "ticks")
import warnings
warnings.filterwarnings('ignore')
from summarytools import dfSummary

from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import r2_score, accuracy_score, confusion_matrix, precision_score, recall_score, f1_score, average_precision_score, precision_recall_curve, roc_curve, auc

from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
## Loading dataset
df = pd.read_csv("loan_approval_data.csv")

# %% [markdown]
# ### 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
## Checking the first 5 rows from the dataset
df.head(15)
# Out:
#      loan_id gender married  dependents     education self_employed  \
# 0   lp001002   male      no         0.0      graduate            no
# 1   lp001003   male     yes         1.0      graduate            no
# 2   lp001005   male     yes         0.0      graduate           yes
# 3   lp001006   male     yes         0.0  not graduate            no
# 4   lp001008   male      no         0.0      graduate            no
# 5   lp001011   male     yes         2.0      graduate           yes
# 6   lp001013   male     yes         0.0  not graduate            no
# 7   lp001014   male     yes         3.0      graduate            no
# 8   lp001018   male     yes         2.0      graduate            no
# 9   lp001020   male     yes         1.0      graduate            no
# 10  lp001024   male     yes         2.0      graduate            no
# 11  lp001027   male     yes         2.0      graduate           NaN
# 12  lp001028   male     yes         2.0      graduate            no
# 13  lp001029   male      no         0.0      graduate            no
# 14  lp001030   male     yes         2.0      graduate            no
#
#     applicantincome  coapplicantincome  loanamount  loan_amount_term  \
# 0              5849                0.0         NaN             360.0
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# 3              2583             2358.0       120.0             360.0
# 4              6000                0.0       141.0             360.0
# 5              5417             4196.0       267.0             360.0
# 6              2333             1516.0        95.0             360.0
# 7              3036             2504.0       158.0             360.0
# 8              4006             1526.0       168.0             360.0
# 9             12841            10968.0       349.0             360.0
# 10             3200              700.0        70.0             360.0
# 11             2500             1840.0       109.0             360.0
# 12             3073             8106.0       200.0             360.0
# 13             1853             2840.0       114.0             360.0
# 14             1299             1086.0        17.0             120.0
#
#     credit_history property_area loan_status
# 0              1.0         urban           y
# 1              1.0         rural           n
# 2              1.0         urban           y
# 3              1.0         urban           y
# 4              1.0         urban           y
# 5              1.0         urban           y
# 6              1.0         urban           y
# 7              0.0     semiurban           n
# 8              1.0         urban           y
# 9              1.0     semiurban           n
# 10             1.0         urban           y
# 11             1.0         urban           y
# 12             1.0         urban           y
# 13             1.0         rural           n
# 14             1.0         urban           y

# %%
## Checking the shape of the dataset
df.shape
# Out:
# (614, 13)

# %%
## Gaining the basic information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   loan_id            614 non-null    object
#  1   gender             601 non-null    object
#  2   married            611 non-null    object
#  3   dependents         599 non-null    float64
#  4   education          614 non-null    object
#  5   self_employed      582 non-null    object
#  6   applicantincome    614 non-null    int64
#  7   coapplicantincome  614 non-null    float64
#  8   loanamount         592 non-null    float64
#  9   loan_amount_term   600 non-null    float64
#  10  credit_history     564 non-null    float64
#  11  property_area      614 non-null    object
#  12  loan_status        614 non-null    object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 62.5+ KB

# %%
## Checkiing the size of data
df.size
# Out:
# 7982

# %%
## Checkining the dimension of dataframe
df.ndim
# Out:
# 2

# %%
## Checking the dimension of series in the dataframe
df["gender"].ndim
# Out:
# 1

# %%
## Checking the statistical summary of the dataset
df.describe()
# Out:
#        dependents  applicantincome  coapplicantincome  loanamount  \
# count  599.000000       614.000000         614.000000  592.000000
# mean     0.762938      5403.459283        1621.245798  146.412162
# std      1.015216      6109.041673        2926.248369   85.587325
# min      0.000000       150.000000           0.000000    9.000000
# 25%      0.000000      2877.500000           0.000000  100.000000
# 50%      0.000000      3812.500000        1188.500000  128.000000
# 75%      2.000000      5795.000000        2297.250000  168.000000
# max      3.000000     81000.000000       41667.000000  700.000000
#
#        loan_amount_term  credit_history
# count         600.00000      564.000000
# mean          342.00000        0.842199
# std            65.12041        0.364878
# min            12.00000        0.000000
# 25%           360.00000        1.000000
# 50%           360.00000        1.000000
# 75%           360.00000        1.000000
# max           480.00000        1.000000

# %%
## Checking the statistical summary of dataset -- for object type
df.describe(include = 'O')
# Out:
#          loan_id gender married education self_employed property_area  \
# count        614    601     611       614           582           614
# unique       614      2       2         2             2             3
# top     lp001002   male     yes  graduate            no     semiurban
# freq           1    489     398       480           500           233
#
#        loan_status
# count          614
# unique           2
# top              y
# freq           422

# %%
## Checking the Percentage of null values in a specific column of the dataset
df.isnull().sum()/len(df) * 100
# Out:
# loan_id              0.000000
# gender               2.117264
# married              0.488599
# dependents           2.442997
# education            0.000000
# self_employed        5.211726
# applicantincome      0.000000
# coapplicantincome    0.000000
# loanamount           3.583062
# loan_amount_term     2.280130
# credit_history       8.143322
# property_area        0.000000
# loan_status          0.000000
# dtype: float64

# %%
check_duplicate = len(df[df.duplicated()])
if check_duplicate > 0:
   
    df = df.drop_duplicates()

    print(f"\033[1m{check_duplicate} duplicate record(s) found and dropped.\033[0m")
else:
    print("\033[1mNo duplicate records found.\033[0m")
# Out:
# No duplicate records found.

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_a231b thead>tr>th {
#   text-align: left;
# }
# #T_a231b_row0_col0, #T_a231b_row1_col0, #T_a231b_row2_col0, #T_a231b_row3_col0, #T_a231b_row4_col0, #T_a231b_row5_col0, #T_a231b_row6_col0, #T_a231b_row7_col0, #T_a231b_row8_col0, #T_a231b_row9_col0, #T_a231b_row10_col0, #T_a231b_row11_col0, #T_a231b_row12_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_a231b_row0_col1, #T_a231b_row1_col1, #T_a231b_row2_col1, #T_a231b_row3_col1, #T_a231b_row4_col1, #T_a231b_row5_col1, #T_a231b_row6_col1, #T_a231b_row7_col1, #T_a231b_row8_col1, #T_a231b_row9_col1, #T_a231b_row10_col1, #T_a231b_row11_col1, #T_a231b_row12_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_a231b_row0_col2, #T_a231b_row1_col2, #T_a231b_row2_col2, #T_a231b_row3_col2, #T_a231b_row4_col2, #T_a231b_row5_col2, #T_a231b_row6_col2, #T_a231b_row7_col2, #T_a231b_row8_col2, #T_a231b_row9_col2, #T_a231b_row10_col2, #T_a231b_row11_col2, #T_a231b_row12_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_a231b_row0_col3, #T_a231b_row1_col3, #T_a231b_row2_col3, #T_a231b_row3_col3, #T_a231b_row4_col3, #T_a231b_row5_col3, #T_a231b_row6_col3, #T_a231b_row7_col3, #T_a231b_row8_col3, #T_a231b_row9_col3, #T_a231b_row10_col3, #T_a231b_row11_col3, #T_a231b_row12_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_a231b_row0_col4, #T_a231b_row1_col4, #T_a231b_row2_col4, #T_a231b_row3_col4, #T_a231b_row4_col4, #T_a231b_row5_col4, #T_a231b_row6_col4, #T_a231b_row7_col4, #T_a231b_row8_col4, #T_a231b_row9_col4, #T_a231b_row10_col4, #T_a231b_row11_col4, #T_a231b_row12_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_a231b_row0_col5, #T_a231b_row1_col5, #T_a231b_row2_col5, #T_a231b_row3_col5, #T_a231b_row4_col5, #T_a231b_row5_col5, #T_a231b_row6_col5, #T_a231b_row7_col5, #T_a231b_row8_col5, #T_a231b_row9_col5, #T_a231b_row10_col5, #T_a231b_row11_col5, #T_a231b_row12_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_a231b">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 614 x 13<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_a231b_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a231b_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a231b_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_a231b_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_a231b_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_a231b_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a231b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a231b_row0_col1" class="data row0 col1" ><strong>loan_id</strong><br>[object]</td>
#       <td id="T_a231b_row0_col2" class="data row0 col2" >1. lp001002<br>2. lp002328<br>3. lp002305<br>4. lp002308<br>5. lp002314<br>6. lp002315<br>7. lp002317<br>8. lp002318<br>9. lp002319<br>10. lp002332<br>11. other</td>
#       <td id="T_a231b_row0_col3" class="data row0 col3" >1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>1 (0.2%)<br>604 (98.4%)</td>
#       <td id="T_a231b_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a231b_row1_col1" class="data row1 col1" ><strong>gender</strong><br>[object]</td>
#       <td id="T_a231b_row1_col2" class="data row1 col2" >1. male<br>2. female<br>3. nan</td>
#       <td id="T_a231b_row1_col3" class="data row1 col3" >489 (79.6%)<br>112 (18.2%)<br>13 (2.1%)</td>
#       <td id="T_a231b_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row1_col5" class="data row1 col5" >13<br>(2.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a231b_row2_col1" class="data row2 col1" ><strong>married</strong><br>[object]</td>
#       <td id="T_a231b_row2_col2" class="data row2 col2" >1. yes<br>2. no<br>3. nan</td>
#       <td id="T_a231b_row2_col3" class="data row2 col3" >398 (64.8%)<br>213 (34.7%)<br>3 (0.5%)</td>
#       <td id="T_a231b_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row2_col5" class="data row2 col5" >3<br>(0.5%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a231b_row3_col1" class="data row3 col1" ><strong>dependents</strong><br>[float64]</td>
#       <td id="T_a231b_row3_col2" class="data row3 col2" >1. 0.0<br>2. 1.0<br>3. 2.0<br>4. 3.0<br>5. nan</td>
#       <td id="T_a231b_row3_col3" class="data row3 col3" >345 (56.2%)<br>102 (16.6%)<br>101 (16.4%)<br>51 (8.3%)<br>15 (2.4%)</td>
#       <td id="T_a231b_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row3_col5" class="data row3 col5" >15<br>(2.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a231b_row4_col1" class="data row4 col1" ><strong>education</strong><br>[object]</td>
#       <td id="T_a231b_row4_col2" class="data row4 col2" >1. graduate<br>2. not graduate</td>
#       <td id="T_a231b_row4_col3" class="data row4 col3" >480 (78.2%)<br>134 (21.8%)</td>
#       <td id="T_a231b_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a231b_row5_col1" class="data row5 col1" ><strong>self_employed</strong><br>[object]</td>
#       <td id="T_a231b_row5_col2" class="data row5 col2" >1. no<br>2. yes<br>3. nan</td>
#       <td id="T_a231b_row5_col3" class="data row5 col3" >500 (81.4%)<br>82 (13.4%)<br>32 (5.2%)</td>
#       <td id="T_a231b_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row5_col5" class="data row5 col5" >32<br>(5.2%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a231b_row6_col1" class="data row6 col1" ><strong>applicantincome</strong><br>[int64]</td>
#       <td id="T_a231b_row6_col2" class="data row6 col2" >Mean (sd) : 5403.5 (6109.0)<br>min < med < max:<br>150.0 < 3812.5 < 81000.0<br>IQR (CV) : 2917.5 (0.9)</td>
#       <td id="T_a231b_row6_col3" class="data row6 col3" >505 distinct values</td>
#       <td id="T_a231b_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a231b_row7_col1" class="data row7 col1" ><strong>coapplicantincome</strong><br>[float64]</td>
#       <td id="T_a231b_row7_col2" class="data row7 col2" >Mean (sd) : 1621.2 (2926.2)<br>min < med < max:<br>0.0 < 1188.5 < 41667.0<br>IQR (CV) : 2297.2 (0.6)</td>
#       <td id="T_a231b_row7_col3" class="data row7 col3" >287 distinct values</td>
#       <td id="T_a231b_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_a231b_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a231b_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_a231b_row8_col1" class="data row8 col1" ><strong>loanamount</strong><br>[float64]</td>
#       <td id="T_a231b_row8_col2" class="data row8 col2" >Mean (sd) : 146.4 (85.6)<br>min < med < max:<br>9.0 < 128.0 < 700.0<br>IQR (CV) : 68.0

# %%
sns.pairplot(df)

# %% [markdown]
# ### Inferences :

# %% [markdown]
# - We have 614 entries and 13 columns in the dataset consisting of integer, float and object type of data.
# - Entire size of data is: (614 x 13) = 7982.
# - We have a 2 dimensional dataset (columns and rows); The entries of the column are 1 dimensional data.
# - We can see that, there are some null entries also in some columns.
# - There are no duplicate records in given dataset.

# %% [markdown]
# ### 3. Check for missing values in the dataset, if present? handle them with appropriate methods and drop redundant features.

# %%
## Checking the Percentage of null values in a specific column of the dataset
df.isnull().sum()/len(df) * 100
# Out:
# loan_id              0.000000
# gender               2.117264
# married              0.488599
# dependents           2.442997
# education            0.000000
# self_employed        5.211726
# applicantincome      0.000000
# coapplicantincome    0.000000
# loanamount           3.583062
# loan_amount_term     2.280130
# credit_history       8.143322
# property_area        0.000000
# loan_status          0.000000
# dtype: float64

# %%
# Filling missing values with appropriate methods
df['gender'].fillna(df['gender'].mode()[0], inplace=True)
df['married'].fillna(df['married'].mode()[0], inplace=True)
df['dependents'].fillna(df['dependents'].median(), inplace=True)
df['self_employed'].fillna(df['self_employed'].mode()[0], inplace=True)
df['loanamount'].fillna(df['loanamount'].mean(), inplace=True)
df['loan_amount_term'].fillna(df['loan_amount_term'].mean(), inplace=True)
df['credit_history'].fillna(df['credit_history'].mean(), inplace=True)

# %%
# from sklearn.impute import SimpleImputer

# # Identify columns with missing values
# columns_with_missing = ['gender', 'married', 'dependents', 'self_employed', 'loanamount', 'loan_amount_term', 'credit_history']

# # Create an instance of the imputer
# imputer = SimpleImputer(strategy='most_frequent')

# # Fill missing values with appropriate methods
# df[columns_with_missing] = imputer.fit_transform(df[columns_with_missing])

# # Drop redundant features
# redundant_features = ['loan_id']
# df = df.drop(redundant_features, axis=1)

# # Verify if there are any missing values remaining
# missing_values = df.isnull().sum()

# print(missing_values)

# %%
# Verify if there are any missing values remaining
df.isnull().sum()
# Out:
# loan_id              0
# gender               0
# married              0
# dependents           0
# education            0
# self_employed        0
# applicantincome      0
# coapplicantincome    0
# loanamount           0
# loan_amount_term     0
# credit_history       0
# property_area        0
# loan_status          0
# dtype: int64

# %%
# Drop redundant features (if identified)
df = df.drop('loan_id', axis=1)

# %%
df['applicantincome']=df['applicantincome']+df['coapplicantincome']
df.drop(['coapplicantincome'], axis=1, inplace=True)

# %%
df['loanamount'] = round(df['loanamount']*1000, 1)

# %%
# df['loanamount'] = df['loanamount'].apply(lambda x: round(x * 1000, 1))

# %%
df.head(2)
# Out:
#   gender married  dependents education self_employed  applicantincome  \
# 0   male      no         0.0  graduate            no           5849.0
# 1   male     yes         1.0  graduate            no           6091.0
#
#    loanamount  loan_amount_term  credit_history property_area loan_status
# 0    146412.2             360.0             1.0         urban           y
# 1    128000.0             360.0             1.0         rural           n

# %% [markdown]
# ### 4. Visualize the distribution of the target column 'loan_status' with respect to various categorical features and write your observations.

# %%
print(df.columns)
# Out:
# Index(['gender', 'married', 'dependents', 'education', 'self_employed',
#        'applicantincome', 'loanamount', 'loan_amount_term', 'credit_history',
#        'property_area', 'loan_status'],
#       dtype='object')

# %%
# Plot loan_status distribution with respect to gender
plt.figure(figsize=(5, 5))
sns.countplot(x='gender', hue='loan_status', data=df)
plt.title("Loan Status Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
# Plot loan_status distribution with respect to gender using a stacked bar plot
plt.figure(figsize=(5, 5))
gender_loan_status = df.groupby(['gender', 'loan_status']).size().unstack()
gender_loan_status.plot(kind='bar', stacked=True)
plt.title("Loan Status Distribution by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title='Loan Status')
plt.show()

# %%
# Plot loan_status distribution with respect to married status
plt.figure(figsize=(5, 5))
sns.countplot(x='married', hue='loan_status', data=df)
plt.title("Loan Status Distribution by Marital Status")
plt.xlabel("Married")
plt.ylabel("Count")
plt.show()

# %%
# Plot loan_status distribution with respect to married status using a pie chart
plt.figure(figsize=(8, 8))
df.groupby(['married', 'loan_status']).size().unstack().plot(kind='pie', autopct='%1.1f%%', subplots=True)
plt.title("Loan Status Distribution by Marital Status")
plt.xlabel("Married")
plt.ylabel("")
plt.legend(loc="upper right")
plt.show()

# %%
# Plot loan_status distribution with respect to education
plt.figure(figsize=(5, 5))
sns.countplot(x='education', hue='loan_status', data=df)
plt.title("Loan Status Distribution by Education")
plt.xlabel("Education")
plt.ylabel("Count")
plt.show()

# %%
# Plot loan_status distribution with respect to education using a stacked percentage bar plot
plt.figure(figsize=(5, 5))
edu_loan_status = df.groupby(['education', 'loan_status']).size().unstack()
edu_loan_status.div(edu_loan_status.sum(axis=1), axis=0).plot(kind='bar', stacked=True)
plt.title("Loan Status Distribution by Education")
plt.xlabel("Education")
plt.ylabel("Percentage")
plt.show()

# %%
# Plot loan_status distribution with respect to property area
plt.figure(figsize=(5, 5))
sns.countplot(x='property_area', hue='loan_status', data=df)
plt.title("Loan Status Distribution by Property Area")
plt.xlabel("Property Area")
plt.ylabel("Count")
plt.show()

# %%
# Plot loan_status distribution with respect to property area using a heatmap
plt.figure(figsize=(5, 5))
prop_loan_status = df.groupby(['property_area', 'loan_status']).size().unstack()
sns.heatmap(prop_loan_status, annot=True, cmap='Blues')
plt.title("Loan Status Distribution by Property Area")
plt.xlabel("Loan Status")
plt.ylabel("Property Area")
plt.show()

# %%
categorical_features=['gender','married','dependents','education','self_employed','applicantincome',
                     'loanamount','loan_amount_term','credit_history','property_area']
i=1
plt.figure(figsize=(30,25))
for feature in categorical_features:
    plt.subplot(6,3,i)
    sns.countplot(x=feature,hue='loan_status',data=df)
    i+=1

# %% [markdown]
# ### <font color=#338CFF>Inferences :</font>

# %% [markdown]
# - **Loan Status Distribution by Gender :** It can be observed that there is a higher number of loan approvals among male applicants compared to female applicants. This suggests a disparity in loan approval rates based on gender, with a greater number of loans being approved for male applicants in the dataset.
#
# - **Loan Status Distribution by Marital Status:** Among the applicants, the rate of loan approvals is higher for those who are married compared to those who are not married. This indicates that marital status is an influential factor in the loan approval decision.
#
# - **Loan Status Distribution by Education:** Among the applicants, it is observed that a higher number of loans are approved for graduated applicants compared to those who are non-graduated. However, the rate of non-approval is relatively higher for non-graduated applicants. This suggests that graduation may play a significant role in the loan approval decision, with a higher likelihood of loan approval for individuals who have completed their education.
#
# - **Loan Status Distribution by Property Area:** It can be inferred that the semi-urban area is the most favorable property area in terms of loan approvals, followed by urban and rural areas. The loan approval and non-approval ratio being greater in the semi-urban area further strengthens this observation.

# %% [markdown]
# ### 5. Encode the categorical data.

# %%
## Checking the categorical columns which are present.
df.select_dtypes('object').columns
# Out:
# Index(['gender', 'married', 'education', 'self_employed', 'property_area',
#        'loan_status'],
#       dtype='object')

# %%
df['gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['married'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['education'].unique()
# Out:
# array(['graduate', 'not graduate'], dtype=object)

# %%
df['self_employed'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['property_area'].unique()
# Out:
# array(['urban', 'rural', 'semiurban'], dtype=object)

# %%
df['loan_status'].unique()
# Out:
# array(['y', 'n'], dtype=object)

# %%
# ## Manual Encoding :
# df['gender'] = df['gender'].replace({'male':0, 'female':1})

# df['married'] = df['married'].replace({'no':0, 'yes':1})

# df['education'] = df['education'].replace({'graduate':0, 'not graduate':1})

# df['self_employed'] = df['self_employed'].replace({'no':0, 'yes':1})

# df['property_area'] = df['property_area'].replace({'urban':0, 'rural':1, 'semiurban':2})

# df['loan_status'] = df['loan_status'].replace({'y':0, 'n':1})

# %%
## Performimg label encoding
for col in df.select_dtypes('object').columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df['gender'].unique()
# Out:
# array([1, 0])

# %%
df['married'].unique()
# Out:
# array([0, 1])

# %%
df['education'].unique()
# Out:
# array([0, 1])

# %%
df['self_employed'].unique()
# Out:
# array([0, 1])

# %%
df['property_area'].unique()
# Out:
# array([2, 0, 1])

# %%
df['loan_status'].unique()
# Out:
# array([1, 0])

# %%
## Final dataframe
df.head(2)
# Out:
#    gender  married  dependents  education  self_employed  applicantincome  \
# 0       1        0         0.0          0              0           5849.0
# 1       1        1         1.0          0              0           6091.0
#
#    loanamount  loan_amount_term  credit_history  property_area  loan_status
# 0    146412.2             360.0             1.0              2            1
# 1    128000.0             360.0             1.0              0            0

# %% [markdown]
# ### 6. Separate the target and independent features and split the data into train and test.

# %%
## Lets store the target column in the y variable and the rest of the columns in the X variable.
target = df['loan_status']
features = df.drop('loan_status', axis=1)

# %%
# Standardize the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
df.head(2)
# Out:
#    gender  married  dependents  education  self_employed  applicantincome  \
# 0       1        0         0.0          0              0           5849.0
# 1       1        1         1.0          0              0           6091.0
#
#    loanamount  loan_amount_term  credit_history  property_area  loan_status
# 0    146412.2             360.0             1.0              2            1
# 1    128000.0             360.0             1.0              0            0

# %%
# # Create an instance of StandardScaler
# ss = StandardScaler()

# # Define the column indices to standardize
# columns_to_standardize = [5, 6, 7]

# # Standardize the selected columns in the training set
# X_train.iloc[:, columns_to_standardize] = ss.fit_transform(X_train.iloc[:, columns_to_standardize])

# # Standardize the selected columns in the test set
# X_test.iloc[:, columns_to_standardize] = ss.transform(X_test.iloc[:, columns_to_standardize])

# %%
# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(scaled_features, target, test_size=0.3, random_state=42)

print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
print("\033[1mX_train head :\033[0m","\n", X_train[:2])
print("\n")
print("\033[1mX_test head :\033[0m","\n", X_test[:2])
# Out:
# (429, 10) (185, 10)
# (429,) (185,)
# X_train head :
#  [[ 0.47234264  0.72881553 -0.73780632  1.89264089 -0.39260074 -0.34674812
#    0.41191195  0.27985054 -2.41044061  1.22329839]
#  [ 0.47234264  0.72881553 -0.73780632  1.89264089 -0.39260074 -0.20744175
#    0.10227389  0.27985054  0.45164045 -1.31851281]]
#
#
# X_test head :
#  [[ 4.72342640e-01  7.28815525e-01 -7.37806323e-01 -5.28362249e-01
#   -3.92600737e-01  3.18947254e-01  9.71642288e-01  2.79850543e-01
#    4.51640451e-01 -4.76072130e-02]
#  [ 4.72342640e-01  7.28815525e-01 -7.37806323e-01 -5.28362249e-01
#   -3.92600737e-01 -4.20662619e-01 -1.95455019e-01  2.79850543e-01
#    3.17754829e-16 -4.76072130e-02]]

# %% [markdown]
# ### 7. Build any classification model to predict the loan status of the customer and save your model using pickle.

# %%
# take the model, and data as inputs
def fit_n_predict(model, X_train, X_test, y_train, y_test):
    
    # Fit the model with train data
    model.fit(X_train, y_train)
    
    # Making prediction on test data
    pred = model.predict(X_test)
    
    # Calculate the accuracy score
    accuracy = accuracy_score(y_test, pred)
    
    # Calculate the precision score
    precision = precision_score(y_test, pred)
    
    # Calculate the recall score
    recall = recall_score(y_test, pred)
    
    # Calculate the F1 score
    f1 = f1_score(y_test, pred)
    
    # Calculate the average precision score (AUPRC)
    auprc = average_precision_score(y_test, pred)
    
    # Calculate the confusion matrix
    cm = confusion_matrix(y_test, pred)
    
    # return all the metrics
    return accuracy, precision, recall, f1, auprc, cm

# %%
# Intializing the models
lr = LogisticRegression()
nb = GaussianNB()
knn = KNeighborsClassifier()
dt = DecisionTreeClassifier()
rf = RandomForestClassifier()
adb = AdaBoostClassifier()
gb = GradientBoostingClassifier()
svm = SVC(probability=True)

estimators = [('rf', rf), ('knn', knn), ('gb', gb), ('adb', adb), ('svm', svm)]
sc = StackingClassifier(estimators=estimators, final_estimator=rf)

# %%
result = pd.DataFrame(columns=['Accuracy', 'Precision', 'Recall', 'F1 Score', 'AUPRC'])

for model, model_name in zip([lr, nb, knn, dt, rf, adb, gb, sc, svm],
                             ['Logistic Regression', 'Naive Bayes', 'KNN', 'Decision tree',
                              'Random Forest', 'Ada Boost', 'Gradient Boost', 'Stacking', 'SVM']):
    accuracy, precision, recall, f1, auprc, cm = fit_n_predict(model, X_train, X_test, y_train, y_test)
    result.loc[model_name] = [accuracy, precision, recall, f1, auprc]
    print("\033[1mModel Name : \033[0m", model_name)
    print("\033[1mAccuracy :\033[0m", accuracy)
    print("\033[1mPrecision :\033[0m", precision)
    print("\033[1mRecall :\033[0m", recall)
    print("\033[1mF1 Score :\033[0m", f1)
    print("\033[1mAUPRC : \033[0m", auprc)
    print("\033[1mConfusion Matrix :\033[0m")
    print(cm)
    print()
# Out:
# Model Name :  Logistic Regression
# Accuracy : 0.7837837837837838
# Precision : 0.7564102564102564
# Recall : 0.9833333333333333
# F1 Score : 0.8550724637681159
# AUPRC :  0.7546142296142295
# Confusion Matrix :
# [[ 27  38]
#  [  2 118]]
#
# Model Name :  Naive Bayes
# Accuracy : 0.7783783783783784
# Precision : 0.7581699346405228
# Recall : 0.9666666666666667
# F1 Score : 0.8498168498168498
# AUPRC :  0.7545192251074604
# Confusion Matrix :
# [[ 28  37]
#  [  4 116]]
#
# Model Name :  KNN
# Accuracy : 0.7513513513513513
# Precision : 0.75
# Recall : 0.925
# F1 Score : 0.8283582089552239
# AUPRC :  0.7423986486486487
# Confusion Matrix :
# [[ 28  37]
#  [  9 111]]
#
# Model Name :  Decision tree
# Accuracy : 0.7243243243243244
# Precision : 0.7948717948717948
# Recall : 0.775
# F1 Score : 0.7848101265822786
# AUPRC :  0.761971586971587
# Confusion Matrix :
# [[41 24]
#  [27 93]]
#
# Model Name :  Random Forest
# Accuracy : 0.7891891891891892
# Precision : 0.7718120805369127
# Recall : 0.9583333333333334
# F1 Score : 0.8550185873605949
# AUPRC :  0.7666802708749018
# Confusion Matrix :
# [[ 31  34]
#  [  5 115]]
#
# Model Name :  Ada Boost
# Accuracy : 0.7945945945945946
# Precision : 0.7662337662337663
# Recall : 0.9833333333333333
# F1 Score : 0.8613138686131387
# AUPRC :  0.7642740142740143
# Confusion Matrix :
# [[ 29  36]
#  [  2 118]]
#
# Model Name :  Gradient Boost
# Accuracy : 0.7675675675675676
# Precision : 0.7655172413793103
# Recall : 0.925
# F1 Score : 0.8377358490566038
# AUPRC :  0.7567520969245107
# Confusion Matrix :
# [[ 31  34]
#  [  9 111]]
#
# Model Name :  Stacking
# Accuracy : 0.772972972972973
# Precision : 0.7671232876712328
# Recall : 0.9333333333333333
# F1 Score : 0.8421052631578947
# AUPRC :  0.7592249784030606
# Confusion Matrix :
# [[ 31  34]
#  [  8 112]]
#
# Model Name :  SVM
# Accuracy : 0.7837837837837838
# Precision : 0.7564102564102564
# Recall : 0.9833333333333333
# F1 Score : 0.8550724637681159
# AUPRC :  0.7546142296142295
# Confusion Matrix :
# [[ 27  38]
#  [  2 118]]

# %%
# Plot ROC curve for each model
plt.figure()
for model, model_name in zip([lr, nb, knn, dt, rf, adb, gb, sc, svm],
                             ['Logistic Regression', 'Naive Bayes', 'KNN', 'Decision tree',
                              'Random Forest', 'Ada Boost', 'Gradient Boost', 'Stacking', 'SVM']):
    if model_name != 'Naive Bayes':
        if hasattr(model, 'predict_proba'):
            pred_prob = model.predict_proba(X_test)[:, 1]
            fpr, tpr, thresholds = roc_curve(y_test, pred_prob)
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=model_name + ' (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
# Plot precision-recall curve for each model
plt.figure()
for model, model_name in zip([lr, nb, knn, dt, rf, adb, gb, sc, svm],
                             ['Logistic Regression', 'Naive Bayes', 'KNN', 'Decision tree',
                              'Random Forest', 'Ada Boost', 'Gradient Boost', 'Stacking', 'SVM']):
    if model_name != 'Naive Bayes':
        if hasattr(model, 'predict_proba'):
            pred_prob = model.predict_proba(X_test)[:, 1]
            precision, recall, thresholds = precision_recall_curve(y_test, pred_prob)
            pr_auc = auc(recall, precision)
            plt.plot(recall, precision, label=model_name + ' (AUC = %0.2f)' % pr_auc)
        else:
            decision_scores = model.decision_function(X_test)
            precision, recall, thresholds = precision_recall_curve(y_test, decision_scores)
            pr_auc = auc(recall, precision)
            plt.plot(recall, precision, label=model_name + ' (AUC = %0.2f)' % pr_auc)

plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(rf, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("\033[1mCross-Validation Scores (Random Forest Classifier) :\033[0m", cv_scores)
print("\033[1mMean CV Score (Random Forest Classifier) :\033[0m", cv_scores.mean())
# Out:
# Cross-Validation Scores (Random Forest Classifier) : [0.8255814  0.81395349 0.76744186 0.80232558 0.8       ]
# Mean CV Score (Random Forest Classifier) : 0.8018604651162791

# %%
from sklearn.model_selection import GridSearchCV

# Perform grid search for parameter tuning
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10]
}

grid_search = GridSearchCV(rf, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print("\033[1mBest Parameters (Random Forest Classifier) :\033[0m", grid_search.best_params_)
print("\033[1mBest Score (Random Forest Classifier) :\033[0m", grid_search.best_score_)
# Out:
# Best Parameters (Random Forest Classifier) : {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 100}
# Best Score (Random Forest Classifier) : 0.8181121751025993

# %%
# Plot feature importances
importances = grid_search.best_estimator_.feature_importances_
feature_names = df.drop('loan_status', axis=1).columns

plt.figure(figsize=(10, 6))
plt.bar(feature_names, importances)
plt.title('Feature Importances for Random Forest Classifier Model')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.xticks(rotation=90)
plt.show()

# %%
# Evaluate the model on the testing set
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)

# Print the evaluation metrics
print("\033[1mAccuracy (Random Forest Classifier) :\033[0m", accuracy)
print("\033[1mPrecision (Random Forest Classifier) :\033[0m", precision)
print("\033[1mRecall (Random Forest Classifier) :\033[0m", recall)
print("\033[1mF1 Score (Random Forest Classifier) :\033[0m", f1)
# Out:
# Accuracy (Random Forest Classifier) : 0.7891891891891892
# Precision (Random Forest Classifier) : 0.7612903225806451
# Recall (Random Forest Classifier) : 0.9833333333333333
# F1 Score (Random Forest Classifier) : 0.8581818181818182

# %%
# Perform cross-validation
cv_scores = cross_val_score(lr, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("\033[1mCross-Validation Scores (Logistic Regression) :\033[0m", cv_scores)
print("\033[1mMean CV Score (Logistic Regression) :\033[0m", cv_scores.mean())
# Out:
# Cross-Validation Scores (Logistic Regression) : [0.8372093  0.8255814  0.8255814  0.81395349 0.8       ]
# Mean CV Score (Logistic Regression) : 0.8204651162790698

# %%
from sklearn.model_selection import GridSearchCV
# Perform grid search for parameter tuning

param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

grid_search = GridSearchCV(lr, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best parameters and best score
print("\033[1mBest Parameters (Logistic Regression) :\033[0m", grid_search.best_params_)
print("\033[1mBest Score (Logistic Regression) :\033[0m", grid_search.best_score_)
# Out:
# Best Parameters (Logistic Regression) : {'C': 0.001, 'penalty': 'l2', 'solver': 'liblinear'}
# Best Score (Logistic Regression) : 0.8204651162790698

# %%
# Plot feature importances
importances = grid_search.best_estimator_.coef_[0]
feature_names = df.drop('loan_status', axis=1).columns

plt.figure(figsize=(10, 6))
plt.bar(feature_names, importances)
plt.title('Feature Importances for Logistic Regression Model')
plt.xlabel('Features')
plt.ylabel('Importance')
plt.xticks(rotation=90)
plt.show()

# %%
# Evaluate the model on the testing set
best_model = grid_search.best_estimator_
predictions = best_model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
f1 = f1_score(y_test, predictions)

# Print the evaluation metrics
print("\033[1mAccuracy (Logistic Regression) :\033[0m", accuracy)
print("\033[1mPrecision (Logistic Regression) :\033[0m", precision)
print("\033[1mRecall (Logistic Regression) :\033[0m", recall)
print("\033[1mF1 Score (Logistic Regression) :\033[0m", f1)
# Out:
# Accuracy (Logistic Regression) : 0.7837837837837838
# Precision (Logistic Regression) : 0.7564102564102564
# Recall (Logistic Regression) : 0.9833333333333333
# F1 Score (Logistic Regression) : 0.8550724637681159

# %%
# Create the AdaBoostClassifier
ab = AdaBoostClassifier()

# Perform cross-validation
cv_scores_ab = cross_val_score(adb, X_train, y_train, cv=5, scoring='accuracy')

# Print the cross-validation scores
print("\033[1mCross-Validation Scores (AdaBoost):\033[0m", cv_scores_ab)
print("\033[1mMean CV Score (AdaBoost):\033[0m", cv_scores_ab.mean())
# Out:
# Cross-Validation Scores (AdaBoost): [0.80232558 0.79069767 0.77906977 0.81395349 0.77647059]
# Mean CV Score (AdaBoost): 0.7925034199726402

# %%
# Define the parameter grid for AdaBoost
param_grid_ab = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.1, 0.5, 1.0]
}

# Perform grid search for parameter tuning
grid_search_ab = GridSearchCV(ab, param_grid_ab, cv=5, scoring='accuracy')
grid_search_ab.fit(X_train, y_train)

# Print the best parameters and best score
print("\033[1mBest Parameters (AdaBoost):\033[0m", grid_search_ab.best_params_)
print("\033[1mBest Score (AdaBoost):\033[0m", grid_search_ab.best_score_)
# Out:
# Best Parameters (AdaBoost): {'learning_rate': 0.1, 'n_estimators': 50}
# Best Score (AdaBoost): 0.818139534883721

# %%
# Plot feature importances (if applicable for the chosen algorithm)
best_base_estimator = grid_search_ab.best_estimator_.base_estimator

if hasattr(best_base_estimator, 'feature_importances_'):
    importances_ab = best_base_estimator.feature_importances_
    plt.figure(figsize=(10, 6))
    plt.bar(feature_names, importances_ab)
    plt.title('Feature Importances (AdaBoost)')
    plt.xlabel('Features')
    plt.ylabel('Importance')
    plt.xticks(rotation=90)
    plt.show()
else:
    print("The base estimator of AdaBoost doesn't have feature importances.")
# Out:
# The base estimator of AdaBoost doesn't have feature importances.

# %%
# Evaluate the model on the testing set
best_model_ab = grid_search_ab.best_estimator_
predictions_ab = best_model_ab.predict(X_test)
accuracy_ab = accuracy_score(y_test, predictions_ab)
precision_ab = precision_score(y_test, predictions_ab)
recall_ab = recall_score(y_test, predictions_ab)
f1_ab = f1_score(y_test, predictions_ab)

# Print the evaluation metrics
print("\033[1mAccuracy (AdaBoost):\033[0m", accuracy_ab)
print("\033[1mPrecision (AdaBoost):\033[0m", precision_ab)
print("\033[1mRecall (AdaBoost):\033[0m", recall_ab)
print("\033[1mF1 Score (AdaBoost):\033[0m", f1_ab)

# %% [markdown]
# ### Creating a pickle file with an extension as .pkl

# %%
import pickle

## Saving model to disk
pickle.dump(rf, open('model.pkl','wb'))

# %% [markdown]
# ## Thank You..
